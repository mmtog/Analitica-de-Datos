# %% [markdown]
# <a href="https://colab.research.google.com/github/mmtog/Analitica-de-Datos/blob/main/hola_mundooo_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerías:: numpy y matplotlib
import numpy as np
from matplotlib import pyplot as plt

# %%
#Definimos 2 arreglos de dimensión 190
ys = 200 + np.random.randn(100)
x = np.arange (0,100,1)

# %%
#Graficamos los arreglos en un plano 20
plt.plot (x,ys, '.')
plt.fill_between(x,ys,195,facecolor='r', alpha=0.6)
#COMENTARIOOOOO
#comentario 2 
#Agregamos título a la gráfica
plt.title("Sample Visualization")
plt.xlabel("eje x ", size =16)
plt.ylabel("eje y", size = 16)
plt.show()
